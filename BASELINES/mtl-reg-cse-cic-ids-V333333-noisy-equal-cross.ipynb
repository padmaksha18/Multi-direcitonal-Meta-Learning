# %%
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch
import torch.nn as nn
import sys
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score
import matplotlib.pyplot as plt
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# %cd /content/gdrive/MyDrive/MTL-RED/
# Out:
# /content/gdrive/MyDrive/MTL-RED

# %%
import sys
import io
import torch
import numpy as np
from torch.utils.data import DataLoader, TensorDataset

# Define a Tee class that writes to both console and log file

class Tee:
    def __init__(self, file_path):
        self.file = open(file_path, "a")  # Open in append mode (real-time updates)
        self.stdout = sys.__stdout__  # Store reference to original console output

    def write(self, message):
        self.stdout.write(message)  # Print to console immediately
        self.file.write(message)  # Write to file
        self.stdout.flush()  # Ensure console updates immediately
        self.file.flush()  # Ensure log file updates immediately

    def flush(self):
        self.stdout.flush()
        self.file.flush()

    def close(self):
        self.file.close()





# # Initialize the log file for capturing all output
# log_filename = "hyperparam_search_output.log"
# tee = Tee(log_filename)  # Create a Tee instance

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
import pandas as pd
import numpy as np

def load_csv(path, label_val):
    """
    Loads a CSV file and assigns the correct label.
    Ensures that the 'Label' column is correctly set (0 for benign, 1 for attack).
    """
    df = pd.read_csv(path)

    # Ensure all labels are correctly assigned
    df['Label'] = label_val
    return df

def add_noise(df, epsilon=1e-6):
    """
    Adds small Gaussian noise to all numerical columns except 'Label'.
    Helps prevent numerical stability issues in Mutual Information calculations.
    """
    numeric_cols = df.select_dtypes(include=[np.number]).columns  # Find numerical columns
    numeric_cols = numeric_cols.drop("Label", errors="ignore")  # Exclude the 'Label' column

    noise = np.random.randn(*df[numeric_cols].shape) * epsilon
    df[numeric_cols] += noise  # Apply noise only to selected columns

    return df

# File paths for training and OOD datasets
datasets = {
    "benign_train": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_LAST_1.csv", 0),
    "attack1": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SOLARIS.csv", 1),
    "attack2": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_INFIL.csv", 1),
    "attack3": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_OOD_BOT.csv", 1),
    "attack4": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_GOLDEN_EYE.csv", 1),
    "benign_val": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_TEST.csv", 0),
    "attack_ood4": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_RARE.csv", 1),
    "attack_ood5": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SlowHTTPTest.csv", 1),
    "attack_ood6": ("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_HOIC.csv", 1),
}

# Load and preprocess each dataset
processed_datasets = {}
for name, (path, label) in datasets.items():
    df = load_csv(path, label)

    # Add small noise to numerical features (except "Label")
    df = add_noise(df)

    # Save the processed dataset with "_FIXED.csv" suffix
    save_path = path.replace(".csv", "_FIXED.csv")
    df.to_csv(save_path, index=False)

    # Store in dictionary for later use
    processed_datasets[name] = df

    # Print status
    print(f"✅ Processed & saved {name}: {save_path}")
# Out:
# ✅ Processed & saved benign_train: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_LAST_1_FIXED.csv
# ✅ Processed & saved attack1: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SOLARIS_FIXED.csv
# ✅ Processed & saved attack2: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_INFIL_FIXED.csv
# ✅ Processed & saved attack3: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_OOD_BOT_FIXED.csv
# ✅ Processed & saved attack4: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_GOLDEN_EYE_FIXED.csv
# ✅ Processed & saved benign_val: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_TEST_FIXED.csv
# ✅ Processed & saved attack_ood4: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_RARE_FIXED.csv
# ✅ Processed & saved attack_ood5: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SlowHTTPTest_FIXED.csv
# ✅ Processed & saved attack_ood6: /content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_HOIC_FIXED.csv

# %%
#botnet = pd.read_csv("/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_OOD_BOT.csv")

# %%
# File paths for CSV files (adjust paths as needed)
benign_path_train   = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_LAST_1_FIXED.csv"
attack_path1  = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SOLARIS_FIXED.csv"
attack_path2  = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_INFIL_FIXED.csv"
attack_path3  = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_OOD_BOT_FIXED.csv"
attack_path4  = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_GOLDEN_EYE_FIXED.csv"

# Load CSVs into DataFrames (optionally subsample for quicker experiments)
# Validation data uses one benign file + an OOD attack dataset
benign_val_path  = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_TEST_FIXED.csv"
attack_ood_path4 = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_RARE_FIXED.csv"
attack_ood_path5 = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SlowHTTPTest_FIXED.csv"
attack_ood_path6 = "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_HOIC_FIXED.csv"

# %%
# Take just features
import pandas as pd

# Define file paths
file_paths = {
    "attack_path1": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SOLARIS_FIXED.csv",
    "attack_path2": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_INFIL_FIXED.csv",
    "attack_path3": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_OOD_BOT_FIXED.csv",
    "attack_path4" : "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_GOLDEN_EYE_FIXED.csv",
    "benign_val_path": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/BENIGN_TEST_FIXED.csv",
    "attack_ood_path4": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_RARE_FIXED.csv",
    "attack_ood_path5": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_SlowHTTPTest_FIXED.csv",
    "attack_ood_path6": "/content/gdrive/MyDrive/MTL-RED/DATA/CSE_CIC_IDS/TRAIN/TEST_HOIC_FIXED.csv"
}

# Load datasets while ignoring the "Label" column
datasets = {name: pd.read_csv(path, usecols=lambda column: column != "Label") for name, path in file_paths.items()}

# Access individual datasets like this:
attack_path1 = datasets["attack_path1"]
attack_path2 = datasets["attack_path2"]
attack_path3 = datasets["attack_path3"]
attack_path4 = datasets["attack_path4"]
benign_val_path = datasets["benign_val_path"]
attack_ood_path4 = datasets["attack_ood_path4"]
attack_ood_path5 = datasets["attack_ood_path5"]
attack_ood_path6 = datasets["attack_ood_path6"]
# Concatenate the datasets
attack_path33 = pd.concat([attack_path2, attack_path3], ignore_index=True)

# Display first few rows of one dataset to verify
#attack_path33.head()

# %%
attack_ood_path6.shape
# Out:
# (10000, 30)

# %%
def load_csv(path, label_val):
    """
    Loads a CSV file and filters rows by label.
    Assumes the CSV has a 'Label' column.
    """
    df = pd.read_csv(path)
    # Filter for desired label (0 for benign, 1 for attack)
    df = df[df['Label'] == label_val]
    return df

# %%
# Load data (adjust row slicing if needed)
benign_cic       = load_csv(benign_path_train, 0).iloc[:50000]
attack_df1      = load_csv(attack_path1, 1).iloc[:10000]
attack_df2      = load_csv(attack_path2, 1).iloc[:10000]
attack_df3      = load_csv(attack_path3, 1).iloc[:10000]
attack_df4      = load_csv(attack_path4, 1).iloc[:10000]

benign_val_df   = load_csv(benign_val_path, 0).iloc[:10000]     # validation benign
attack_ood_df4  = load_csv(attack_ood_path4, 1).iloc[:500]    # OOD dataset 4
attack_ood_df5  = load_csv(attack_ood_path5, 1).iloc[:10000]    # OOD dataset 5
attack_ood_df6  = load_csv(attack_ood_path6, 1).iloc[:10000]    # OOD dataset 6

# %%
benign_val_df_ood = benign_cic
attack_df3_ood = attack_df3
attack_df4_ood = attack_df4
attack_ood_df4_ood = attack_ood_df4
attack_ood_df5_ood = attack_ood_df5
attack_ood_df6_ood = attack_ood_df6

# 3) Use these 'augmented' OOD datasets in your pipeline
test_datasets = {
    "RARE": attack_ood_df4_ood,
    "SLOWHTTPS": attack_ood_df5_ood,
    "HOIC": attack_ood_df6,
    # etc.
}

# %%
import random
import numpy as np
import pandas as pd

def create_segmented_dataset(
    base_df,
    other_dfs,         # Dict of attack datasets, e.g. { "SOLARIS": df_solaris, ... }
    segment_sizes,     # Dict specifying segment size for each attack dataset
    segment_counts,    # Dict specifying number of insertions for each attack dataset
    test_set=False,
    rare_class=False,  # If True, handle the entire chunk for 'RARE' dataset
    random_seed=42
):
    """
    Creates a dataset by:
      - Using base_df as benign dataset.
      - Splitting attack datasets into **70% train, 30% test**.
      - Inserts attack segments into base_df at **random positions**.
      - Allows **different segment sizes & number of insertions** for training and test.

    Parameters:
    - base_df (DataFrame): Benign dataset.
    - other_dfs (dict): Dict of attack datasets `{ "SOLARIS": df_solaris, ... }`.
    - segment_sizes (dict): Dict of segment sizes for each attack dataset.
    - segment_counts (dict): Dict of number of insertions for each attack dataset.
    - test_set (bool): If True, inserts attack samples from the **30% test split**.
    - rare_class (bool): If True, takes the entire attack dataset.
    - random_seed (int): Seed for reproducibility.

    Returns:
    - final_df (DataFrame): The benign dataset with attack segments inserted.
    """

    random.seed(random_seed)
    np.random.seed(random_seed)

    # ✅ Keep base dataset unchanged
    base_portion = base_df.copy(deep=True)
    final_df = base_portion.copy(deep=True)

    # ✅ Helper: Insert a block at a random position in final_df
    def insert_block_at_random(main_df, block_df):
        if len(main_df) == 0:
            return block_df.reset_index(drop=True)
        pos = random.randint(0, len(main_df))
        top = main_df.iloc[:pos]
        bottom = main_df.iloc[pos:]
        merged = pd.concat([top, block_df, bottom], ignore_index=True)
        return merged.reset_index(drop=True)

    # ✅ Iterate through each attack dataset and insert segments
    for name, attack_df in other_dfs.items():
        # ✅ 70:30 split for attack dataset
        att_split = int(len(attack_df) * 0.70)
        att_train = attack_df.iloc[:att_split]
        att_test = attack_df.iloc[att_split:]

        # ✅ Choose train or test portion
        chunk_df = att_test if test_set else att_train

        if len(chunk_df) == 0:
            print(f"⚠ Warning: Attack dataset '{name}' has NO samples in {'TEST' if test_set else 'TRAIN'} set.")
            continue

        if test_set and rare_class:
            # ✅ RARE case: Take **entire** dataset and insert once
            block_size_local = len(chunk_df)
            final_df = insert_block_at_random(final_df, chunk_df)
            print(f"[create_segmented_dataset] Inserted ENTIRE RARE chunk of size {block_size_local}.")

        else:
            # ✅ Insert multiple segments at random positions
            segment_size = segment_sizes.get(name, 100)  # Default to 100 if not specified
            segment_count = segment_counts.get(name, 1)  # Default to 1 if not specified

            for _ in range(segment_count):
                block_size_local = min(segment_size, len(chunk_df))
                if block_size_local <= 0:
                    continue

                # ✅ Random start position
                start_pos = random.randint(0, max(0, len(chunk_df) - block_size_local))
                segment_block = chunk_df.iloc[start_pos : start_pos + block_size_local]

                final_df = insert_block_at_random(final_df, segment_block)

        print(f"[create_segmented_dataset] Inserted '{name}' (test_set={test_set}, rare={rare_class}).")

    # ✅ Ensure **benign samples match attack samples in TEST SET**
    if test_set:
        attack_count = len(final_df) - len(base_portion)
        benign_test_subset = base_df.sample(n=attack_count, replace=False, random_state=42)
        final_df = pd.concat([final_df, benign_test_subset], ignore_index=True)

    print(f"[create_segmented_dataset] Final {'TEST' if test_set else 'TRAIN'} shape: {final_df.shape}")

    return final_df.reset_index(drop=True)

# %%
#############################################
# 2. Custom Dataset that Converts CSV DataFrames Directly to Tensors
#############################################

class CSVCustomDataset(Dataset):
    def __init__(self, df):
        # Convert numeric columns to float32 for consistency.
        numeric_cols = df.select_dtypes(include=['float64', 'float32']).columns
        df[numeric_cols] = df[numeric_cols].astype(np.float32)
        # Convert features and labels to tensors.
        self.x = torch.tensor(df.loc[:, df.columns != 'Label'].values, dtype=torch.float32)
        self.y = torch.tensor(df['Label'].values, dtype=torch.long)
    def __getitem__(self, index):
        return self.x[index], self.y[index]
    def __len__(self):
        return self.x.size(0)

# %%
import torch
import torch.nn as nn

class MultitaskAutoencoder(nn.Module):
    def __init__(self, D_in, H=20, H2=10, latent_dim=5, dropout_prob=0.3):
        super(MultitaskAutoencoder, self).__init__()

        # Encoder
        self.linear1 = nn.Linear(D_in, H)
        self.lin_bn1 = nn.BatchNorm1d(num_features=H)
        self.linear2 = nn.Linear(H, H2)
        self.lin_bn2 = nn.BatchNorm1d(num_features=H2)
        self.linear3 = nn.Linear(H2, latent_dim)
        self.dropout = nn.Dropout(p=dropout_prob)

        self.classifier = nn.Linear(latent_dim, 2)  # Binary classifier

        # Decoder
        self.fc3 = nn.Linear(latent_dim, H2)
        self.lin_bn3 = nn.BatchNorm1d(num_features=H2)
        self.fc4 = nn.Linear(H2, H)
        self.lin_bn4 = nn.BatchNorm1d(num_features=H)
        self.fc5 = nn.Linear(H, D_in)

        self.activation = nn.LeakyReLU(negative_slope=0.02)

        # Initialize weights
        self._initialize_weights()

    def _initialize_weights(self):
        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                if layer.bias is not None:
                    nn.init.zeros_(layer.bias)

    def encode(self, x):
        x = self.activation(self.lin_bn1(self.linear1(x)))
        x = self.dropout(x)
        x = self.activation(self.lin_bn2(self.linear2(x)))
        x = self.dropout(x)
        return self.linear3(x)  # No activation in latent space

    def decode(self, z):
        z = self.activation(self.lin_bn3(self.fc3(z)))
        z = self.dropout(z)
        z = self.activation(self.lin_bn4(self.fc4(z)))
        return self.fc5(z)  # No activation in the output

    def forward(self, inputs):
        z = self.encode(inputs)
        logits = self.classifier(z)
        reconstruction = self.decode(z)
        return logits, reconstruction, z

# %%
import torch
import torch.nn as nn

class CustomLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.ce_loss = nn.CrossEntropyLoss()
        self.mse_loss = nn.MSELoss()

    def calculate_gram_mat(self, X, sigma):
        x2 = torch.sum(X * X, dim=1, keepdim=True)
        dist = -2.0 * (X @ X.t()) + x2 + x2.t()
        gram = torch.exp(-dist / sigma)
        return gram

    def renyi_entropy(self, X, sigma, alpha=2.0):
        K = self.calculate_gram_mat(X, sigma)
        trace_val = torch.trace(K).clamp_min(1e-12)
        K_norm = K / trace_val
        eigvals, _ = torch.linalg.eigh(K_norm)
        eig_pow = eigvals ** alpha
        H = (1.0 / (1.0 - alpha)) * torch.log2(torch.sum(eig_pow) + 1e-12)
        return H

    def joint_entropy(self, X, Y, s_x, s_y, alpha=2.0):
        Kx = self.calculate_gram_mat(X, s_x)
        Ky = self.calculate_gram_mat(Y, s_y)

        Kx_norm = Kx / torch.trace(Kx).clamp_min(1e-12)
        Ky_norm = Ky / torch.trace(Ky).clamp_min(1e-12)

        Kxy = Kx_norm @ Ky_norm
        Kxy_norm = Kxy / torch.trace(Kxy).clamp_min(1e-12)

        eigvals, _ = torch.linalg.eigh(Kxy_norm)
        eig_pow = eigvals ** alpha
        Hxy = (1.0 / (1.0 - alpha)) * torch.log2(torch.sum(eig_pow) + 1e-12)
        return Hxy

    def mutual_info(self, X, Y, s_x, s_y):
        Hx  = self.renyi_entropy(X, s_x)
        Hy  = self.renyi_entropy(Y, s_y)
        Hxy = self.joint_entropy(X, Y, s_x, s_y)
        Ixy = Hx + Hy - Hxy
        return Ixy

    def forward(self, inputs, recon, latent,
                log_s_x, log_s_y,
                logits, targets,
                lambda_mse, lambda_mi):
        # Always compute classification loss
        class_loss = self.ce_loss(logits, targets)

        # If both regularization weights are zero OR log_s_x/log_s_y is None,
        # then do not compute reconstruction and MI loss.
        if (lambda_mse == 0 and lambda_mi == 0) or (log_s_x is None or log_s_y is None):
            # Total loss is just the classification loss.
            # For consistency, return four values.
            dummy = torch.tensor(0.0, device=inputs.device)
            return class_loss, class_loss, dummy, dummy

        # Otherwise, compute the remaining losses.
        s_x = torch.exp(log_s_x)
        s_y = torch.exp(log_s_y)
        rec_loss = self.mse_loss(recon, inputs)
        mi_val = self.mutual_info(inputs, latent, s_x, s_y)
        total_loss = class_loss + lambda_mse * rec_loss + lambda_mi * mi_val
        return total_loss, class_loss, rec_loss, mi_val

# %%
def train_one_epoch(model, dataloader, optimizer, loss_fn,
                    log_s_x, log_s_y,
                    lambda_mse=0.6, lambda_mi=2.0):
    model.train()
    total_loss, total_ce, total_rec, total_mi = 0.0, 0.0, 0.0, 0.0

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()

        logits, recon, latent = model(X)

        # Compute losses
        t_loss, ce_loss, rec_loss, mi_loss = loss_fn(
            X, recon, latent,
            log_s_x, log_s_y,
            logits, y,
            lambda_mse=lambda_mse,
            lambda_mi=lambda_mi
        )

        t_loss.backward()
        optimizer.step()

        # Accumulate losses
        total_loss += t_loss.item()
        total_ce   += ce_loss.item()
        total_rec  += rec_loss.item()
        total_mi   += mi_loss.item()

    # Compute averages
    num_batches = len(dataloader)
    avg_total_loss = total_loss / num_batches
    avg_ce_loss = total_ce / num_batches
    avg_rec_loss = total_rec / num_batches
    avg_mi_loss = total_mi / num_batches

    # # Print structured training log
    # print("\n📌 Training Results:")
    # print("┌──────────────────┬───────────┐")
    # print(f"│ Total Loss       │ {avg_total_loss:.4f} │")
    # print(f"│ CE Loss          │ {avg_ce_loss:.4f} │")
    # print(f"│ Reconstruction   │ {avg_rec_loss:.4f} │")
    # print(f"│ Mutual Info Loss │ {avg_mi_loss:.4f} │")
    # print("└──────────────────┴───────────┘")

    return avg_total_loss, avg_ce_loss, avg_rec_loss, avg_mi_loss

# %%
import torch.nn.functional as F

def validate(model, dataloader, device):
    """
    Validate the model on the given dataloader.
    During validation, only the classification (CE) loss is computed;
    the reconstruction and MI losses are not used.

    Returns:
        avg_ce_loss: Average classification loss over batches.
        prec: Precision score.
        rec: Recall score.
        acc: Accuracy.
        auc_: AUC score.
    """
    model.eval()
    total_ce = 0.0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            # Forward pass; we ignore the reconstruction and latent outputs.
            logits, _, _ = model(X)

            # Compute only the cross-entropy (classification) loss.
            ce_loss = F.cross_entropy(logits, y)
            total_ce += ce_loss.item()

            preds = torch.argmax(logits, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    num_batches = len(dataloader)
    avg_ce_loss = total_ce / num_batches

    # Compute evaluation metrics
    from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score

    prec = precision_score(all_labels, all_preds, zero_division=0)
    rec  = recall_score(all_labels, all_preds, zero_division=0)
    acc  = accuracy_score(all_labels, all_preds)
    try:
        auc_ = roc_auc_score(all_labels, all_preds)
    except ValueError:
        auc_ = 0.0

    return avg_ce_loss, prec, rec, acc, auc_

# %%
import numpy as np

def generate_hyperparameter_combos():
    """
    Generates 10 key hyperparameter combinations for λ_mse and λ_mi.
    """
    hyperparam_combos = [
        # 1️⃣ Both equal
        (0.1, 0.1), (0.5, 0.5),

        # 2️⃣ One low, one high
        (0.1, 0.9), (0.9, 0.1),

        # 3️⃣ One extreme low, the other extreme high
        (0.0, 1.0), (1.0, 0.0),

        # 4️⃣ Both extreme
        (0.0, 0.0), (1.0, 1.0),

        # 5️⃣ Midpoint asymmetric comparisons
        (0.3, 0.7), (0.7, 0.3),

        # 6️⃣ Nonlinear scaling (logarithmic scale)
        (0.01, 0.99), (0.99, 0.01),
    ]

    return hyperparam_combos

# %%
#

# %%
def hyperparam_search(train_loader, val_loaders, epochs=10, input_dim=10, log_filename="hyperparam_search_output.log"):
    """
    Searches over hyperparameter pairs (λ_mse, λ_mi). If both are zero, the optimizer
    and loss function are modified to ignore the reconstruction and MI terms.
    """
    results = {}
    best_auc = 0.0
    best_params = None

    hyperparam_combos = generate_hyperparameter_combos()

    # Initialize learnable kernel bandwidth parameters ONCE
    log_s_x = torch.nn.Parameter(torch.log(torch.tensor(8.0, device=device)))
    log_s_y = torch.nn.Parameter(torch.log(torch.tensor(8.0, device=device)))

    with open(log_filename, "a") as log_file:
        log_file.write(f"\n=== Starting Hyperparameter Search for {log_filename} ===\n")

        for lam_mse, lam_mi in hyperparam_combos:
            print("=" * 80)
            print(f"🔍 Hyperparameter Search: λ_mse={lam_mse:.3f}, λ_mi={lam_mi:.3f}")
            print("=" * 80)
            log_file.write(f"\n🔍 λ_mse={lam_mse:.3f}, λ_mi={lam_mi:.3f}\n")
            log_file.flush()

            # Reinitialize model for each hyperparameter combination.
            model = MultitaskAutoencoder(D_in=input_dim).to(device)

            # If both λ_mse and λ_mi are zero, we do NOT update the kernel bandwidth parameters.
            if lam_mse == 0 and lam_mi == 0:
                optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
                use_kernel_params = False
            else:
                optimizer = torch.optim.Adam([
                    {"params": model.parameters()},
                    {"params": [log_s_x, log_s_y], "lr": 1e-5}
                ], lr=1e-3, weight_decay=1e-5)
                use_kernel_params = True

            loss_fn = CustomLoss().to(device)

            # Train for a number of epochs.
            for ep in range(1, epochs + 1):
                # Optionally, you can pass the flag 'use_kernel_params' to train_one_epoch
                train_total, train_ce, train_rec, train_mi = train_one_epoch(
                    model, train_loader, optimizer, loss_fn,
                    log_s_x if use_kernel_params else None,
                    log_s_y if use_kernel_params else None,
                    lambda_mse=lam_mse,
                    lambda_mi=lam_mi
                )

                # If using kernel parameters, extract their current values.
                if use_kernel_params:
                    current_s_x = torch.exp(log_s_x).item()
                    current_s_y = torch.exp(log_s_y).item()
                else:
                    current_s_x, current_s_y = None, None

                # Validate on all test datasets.
                test_results = {}
                for dataset_name, test_loader in val_loaders.items():
                    # Note: In validation, you may only need the classification (CE) loss and metrics.
                    # So, our validate() function is adjusted accordingly.
                    val_ce, p, r, a, auc_ = validate(
                        model, test_loader, device  # using a modified validate() that only returns CE and metrics
                    )
                    test_results[dataset_name] = (val_ce, p, r, a, auc_)

                if ep % 3 == 0:
                    print(f"📌 Epoch {ep}/{epochs}")
                    print(f"   🏋️ Training: Total Loss={train_total:.4f} | CE Loss={train_ce:.4f} | Rec Loss={train_rec:.4f} | MI Loss={train_mi:.4f}")
                    if use_kernel_params:
                        print(f"   🔬 Kernel Bandwidths: s_x={current_s_x:.4f} | s_y={current_s_y:.4f}")
                        log_file.write(f"   🔬 Kernel Bandwidths: s_x={current_s_x:.4f} | s_y={current_s_y:.4f}\n")
                    for dataset_name, metrics in test_results.items():
                        print(f"   📊 {dataset_name} - CE Loss={metrics[0]:.4f} | Precision={metrics[1]:.3f} | Recall={metrics[2]:.3f} | Accuracy={metrics[3]:.3f} | AUC={metrics[4]:.3f}")
                        log_file.write(f"   📊 {dataset_name} - CE Loss={metrics[0]:.4f} | Precision={metrics[1]:.3f} | Recall={metrics[2]:.3f} | Accuracy={metrics[3]:.3f} | AUC={metrics[4]:.3f}\n")
                    log_file.flush()

            results[(lam_mse, lam_mi)] = test_results
            avg_auc = np.mean([metrics[4] for metrics in test_results.values()])

            if avg_auc > best_auc:
                best_auc = avg_auc
                best_params = (lam_mse, lam_mi)
                print(f"  [New Best AUC: {best_auc:.4f} at (λ_mse={lam_mse:.3f}, λ_mi={lam_mi:.3f})]")
                log_file.write(f"\n[New Best AUC: {best_auc:.4f} at (λ_mse={lam_mse:.3f}, λ_mi={lam_mi:.3f})]\n")
                log_file.flush()

                # ✅ Save your model
                checkpoint = {
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'epoch': ep,
                    'lambda_mse': lam_mse,
                    'lambda_mi': lam_mi,
                    'log_s_x': log_s_x.detach().cpu() if use_kernel_params else None,
                    'log_s_y': log_s_y.detach().cpu() if use_kernel_params else None
                }

                # Use a descriptive filename
                model_save_path = f"best_model_lambda_mse_{lam_mse:.3f}_lambda_mi_{lam_mi:.3f}.pth"
                torch.save(checkpoint, model_save_path)

                print(f"✅ Best model saved to: {model_save_path}")
                log_file.write(f"✅ Best model saved to: {model_save_path}\n")
                log_file.flush()


    print(f"\n✅ Training complete. Full logs saved to '{log_filename}'.")
    print(f"Best AUC: {best_auc:.4f} at (λ_mse={best_params[0]:.3f}, λ_mi={best_params[1]:.3f})")

    return results, best_auc, best_params

# %%
def run_scenario(train_df, test_datasets, log_filename, scenario_label="?"):
    train_dataset = CSVCustomDataset(train_df)
    train_loader = DataLoader(train_dataset, batch_size=200, shuffle=True)

    if not isinstance(test_datasets, dict):
        raise ValueError("Expected `test_datasets` to be a dictionary, but got", type(test_datasets))

    test_loaders = {
        name: DataLoader(CSVCustomDataset(df), batch_size=50, shuffle=False)
        for name, df in test_datasets.items()
    }

    print(f"\n+++ Running scenario: {scenario_label}, log={log_filename} +++")

    results = hyperparam_search(
        train_loader=train_loader,
        val_loaders=test_loaders,
        epochs=60,
        input_dim=train_dataset.x.shape[1],
        log_filename=log_filename
    )

# %%
def run_all_scenarios(benign_train, benign_test, source_dfs, source_names, ood_dfs, ood_names):
    # training_combos = [ (["SOLARIS"], [df_solaris]), (["SOLARIS","BOTNET"], [df_solaris,df_botnet]) ...]
    training_combos = [
        (["SOLARIS"], {"SOLARIS": source_dfs[0]}),
        (["SOLARIS","BOTNET"], {"SOLARIS": source_dfs[0], "BOTNET": source_dfs[2]}),
        (["SOLARIS","BOTNET","INFIL"], {"SOLARIS": source_dfs[0], "BOTNET": source_dfs[2], "INFIL": source_dfs[1]})
    ]

    for scenario_names, selected_attacks in training_combos:
        scenario_label = "_".join(scenario_names)

        # train -> base=benign_train, others=selected_attacks
        train_df = create_segmented_dataset(
            base_df=benign_train,
            other_dfs=selected_attacks,
            segment_size=100,    # consecutive block size
            segments_count=2,    # e.g. insert 2 segments
            test_set=False
        )

        # Build test datasets for all source + OOD
        test_datasets = {}
        for idx, att_df in enumerate(source_dfs + ood_dfs):
            d_name = source_names[idx] if idx < len(source_dfs) else ood_names[idx - len(source_dfs)]

            # If you want a RARE approach, check d_name
            if d_name=="RARE":
                test_datasets[d_name] = create_segmented_dataset(
                    base_df=benign_test,
                    other_dfs={d_name: att_df},
                    test_set=True,
                    rare_class=True,
                    segment_size=999999  # or 0 - means we take all from rare
                )
            else:
                test_datasets[d_name] = create_segmented_dataset(
                    base_df=benign_test,
                    other_dfs={d_name: att_df},
                    test_set=True,
                    segment_size=50,
                    segments_count=1
                )

        log_filename = f"scenario_segment_{scenario_label}.log"
        run_scenario(train_df, test_datasets, log_filename, scenario_label)

# %%
train_segment_sizes = {
    "SOLARIS": 0,
    "INFIL": 0,
    "BOTNET": 150,
    "GOLDEN_EYE": 150,
    "RARE": 0,
    "SLOWHTTPS": 0,
    "HOIC": 0
}

train_segment_counts = {
    "SOLARIS": 0,   # Insert 5 segments of 200 samples
    "INFIL": 0,     # Insert 3 segments of 100 samples
    "BOTNET": 10,    # Insert 2 segments of 100 samples
    "GOLDEN_EYE": 10, # Insert 4 segments of 100 samples
    "RARE": 0,      # Insert only once
    "SLOWHTTPS": 0,
    "HOIC": 0
}

test_segment_sizes = {
    "SOLARIS": 100,
    "INFIL": 100,
    "BOTNET": 50,
    "GOLDEN_EYE": 50,
    "RARE": 50,  # Take full dataset
    "SLOWHTTPS": 75,
    "HOIC": 75
}

test_segment_counts = {
    "SOLARIS": 5,
    "INFIL": 3,
    "BOTNET": 4,
    "GOLDEN_EYE": 4,
    "RARE": 4,  # Insert once
    "SLOWHTTPS": 5,
    "HOIC": 5
}

# %% [markdown]
# **2 CLASSES, BOTNET, GOLDENEYE, BATCH = 200, 8,8 ; check the plots at the end of the page**

# %%
def main():
    """
    Creates training and test datasets using segment insertion strategy.
    Runs training/validation on SOLARIS, INFIL, BOTNET, GOLDENEYE, RARE, SLOWHTTPS, HOIC.
    """

    # ✅ Train dataset: Use **all source datasets** and insert them into benign.
    train_df = create_segmented_dataset(
        base_df=benign_cic,
        other_dfs={
            "SOLARIS": attack_df1,
            "INFIL": attack_df2,
            "BOTNET": attack_df3,
            "GOLDEN_EYE": attack_df4,
            "HOIC": attack_ood_df6_ood

        },
        segment_sizes=train_segment_sizes,
        segment_counts=train_segment_counts,
        test_set=False
    )

    # ✅ Test datasets: Each attack dataset gets its own test set.
    test_datasets = {
        "SOLARIS": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"SOLARIS": attack_df1},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        ),
        "INFIL": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"INFIL": attack_df2},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        ),
        "BOTNET": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"BOTNET": attack_df3},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        ),
        "GOLDEN_EYE": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"GOLDEN_EYE": attack_df4},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        ),
        "RARE": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"RARE": attack_ood_df4_ood},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True,
            rare_class=True
        ),
        "SLOWHTTPS": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"SLOWHTTPS": attack_ood_df5_ood},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        ),
        "HOIC": create_segmented_dataset(
            base_df=benign_val_df_ood,
            other_dfs={"HOIC": attack_ood_df6_ood},
            segment_sizes=test_segment_sizes,
            segment_counts=test_segment_counts,
            test_set=True
        )
    }

    # ✅ Run scenario
    run_scenario(
        train_df, test_datasets,
        log_filename="segment_insertion_all_datasets.log",
        scenario_label="SegmentCase_AllDatasets"
    )

if __name__ == "__main__":
    main()
# Out:
# [create_segmented_dataset] Inserted 'SOLARIS' (test_set=False, rare=False).
# [create_segmented_dataset] Inserted 'INFIL' (test_set=False, rare=False).
# [create_segmented_dataset] Inserted 'BOTNET' (test_set=False, rare=False).
# [create_segmented_dataset] Inserted 'GOLDEN_EYE' (test_set=False, rare=False).
# [create_segmented_dataset] Inserted 'HOIC' (test_set=False, rare=False).
# [create_segmented_dataset] Final TRAIN shape: (52405, 30)
# [create_segmented_dataset] Inserted 'SOLARIS' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (50405, 30)
# [create_segmented_dataset] Inserted 'INFIL' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (50005, 30)
# [create_segmented_dataset] Inserted 'BOTNET' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (49805, 30)
# [create_segmented_dataset] Inserted 'GOLDEN_EYE' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (49805, 30)
# [create_segmented_dataset] Inserted ENTIRE RARE chunk of size 150.
# [create_segmented_dataset] Inserted 'RARE' (test_set=True, rare=True).
# [create_segmented_dataset] Final TEST shape: (49705, 30)
# [create_segmented_dataset] Inserted 'SLOWHTTPS' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (50155, 30)
# [create_segmented_dataset] Inserted 'HOIC' (test_set=True, rare=False).
# [create_segmented_dataset] Final TEST shape: (50155, 30)
#
# +++ Running scenario: SegmentCase_AllDatasets, log=segment_insertion_all_datasets.log +++
# ================================================================================
# 🔍 Hyperparameter Search: λ_mse=0.100, λ_mi=0.100
# ================================================================================
# 📌 Epoch 3/60
#    🏋️ Training: Total Loss=0.5978 | CE Loss=0.1730 | Rec Loss=0.7338 | MI Loss=3.5147
#    🔬 Kernel Bandwidths: s_x=8.0642 | s_y=8.0529
#    📊 SOLARIS - CE Loss=0.0726 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0654 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0530 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0541 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0546 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0573 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0606 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 6/60
#    🏋️ Training: Total Loss=0.5079 | CE Loss=0.0983 | Rec Loss=0.6328 | MI Loss=3.4631
#    🔬 Kernel Bandwidths: s_x=8.1282 | s_y=8.0994
#    📊 SOLARIS - CE Loss=0.0424 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0411 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0180 | Precision=0.875 | Recall=0.455 | Accuracy=0.998 | AUC=0.727
#    📊 GOLDEN_EYE - CE Loss=0.0203 | Precision=0.888 | Recall=0.515 | Accuracy=0.998 | AUC=0.757
#    📊 RARE - CE Loss=0.0234 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0209 | Precision=0.938 | Recall=0.520 | Accuracy=0.996 | AUC=0.760
#    📊 HOIC - CE Loss=0.0227 | Precision=0.937 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 9/60
#    🏋️ Training: Total Loss=0.4617 | CE Loss=0.0651 | Rec Loss=0.5784 | MI Loss=3.3874
#    🔬 Kernel Bandwidths: s_x=8.1925 | s_y=8.1403
#    📊 SOLARIS - CE Loss=0.0283 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0389 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0098 | Precision=0.952 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0125 | Precision=0.917 | Recall=0.550 | Accuracy=0.998 | AUC=0.775
#    📊 RARE - CE Loss=0.0160 | Precision=0.630 | Recall=0.113 | Accuracy=0.997 | AUC=0.557
#    📊 SLOWHTTPS - CE Loss=0.0159 | Precision=0.950 | Recall=0.507 | Accuracy=0.996 | AUC=0.753
#    📊 HOIC - CE Loss=0.0132 | Precision=0.950 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 12/60
#    🏋️ Training: Total Loss=0.4466 | CE Loss=0.0565 | Rec Loss=0.5481 | MI Loss=3.3537
#    🔬 Kernel Bandwidths: s_x=8.2574 | s_y=8.1801
#    📊 SOLARIS - CE Loss=0.0301 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0384 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0080 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0109 | Precision=0.982 | Recall=0.555 | Accuracy=0.998 | AUC=0.777
#    📊 RARE - CE Loss=0.0140 | Precision=0.895 | Recall=0.113 | Accuracy=0.997 | AUC=0.557
#    📊 SLOWHTTPS - CE Loss=0.0174 | Precision=0.989 | Recall=0.501 | Accuracy=0.996 | AUC=0.751
#    📊 HOIC - CE Loss=0.0126 | Precision=0.990 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 15/60
#    🏋️ Training: Total Loss=0.4343 | CE Loss=0.0493 | Rec Loss=0.5244 | MI Loss=3.3253
#    🔬 Kernel Bandwidths: s_x=8.3229 | s_y=8.2249
#    📊 SOLARIS - CE Loss=0.0296 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0387 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0075 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0099 | Precision=0.983 | Recall=0.570 | Accuracy=0.998 | AUC=0.785
#    📊 RARE - CE Loss=0.0122 | Precision=0.895 | Recall=0.113 | Accuracy=0.997 | AUC=0.557
#    📊 SLOWHTTPS - CE Loss=0.0142 | Precision=0.990 | Recall=0.504 | Accuracy=0.996 | AUC=0.752
#    📊 HOIC - CE Loss=0.0100 | Precision=0.990 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 18/60
#    🏋️ Training: Total Loss=0.4272 | CE Loss=0.0449 | Rec Loss=0.5134 | MI Loss=3.3088
#    🔬 Kernel Bandwidths: s_x=8.3889 | s_y=8.2753
#    📊 SOLARIS - CE Loss=0.0231 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0399 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0040 | Precision=0.966 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0058 | Precision=0.952 | Recall=0.695 | Accuracy=0.999 | AUC=0.847
#    📊 RARE - CE Loss=0.0086 | Precision=0.919 | Recall=0.527 | Accuracy=0.998 | AUC=0.763
#    📊 SLOWHTTPS - CE Loss=0.0050 | Precision=0.981 | Recall=0.957 | Accuracy=1.000 | AUC=0.979
#    📊 HOIC - CE Loss=0.0045 | Precision=0.982 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 21/60
#    🏋️ Training: Total Loss=0.4197 | CE Loss=0.0391 | Rec Loss=0.5094 | MI Loss=3.2970
#    🔬 Kernel Bandwidths: s_x=8.4554 | s_y=8.3308
#    📊 SOLARIS - CE Loss=0.0184 | Precision=0.985 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0404 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0039 | Precision=0.975 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0050 | Precision=0.973 | Recall=0.890 | Accuracy=0.999 | AUC=0.945
#    📊 RARE - CE Loss=0.0077 | Precision=0.951 | Recall=0.647 | Accuracy=0.999 | AUC=0.823
#    📊 SLOWHTTPS - CE Loss=0.0052 | Precision=0.986 | Recall=0.952 | Accuracy=1.000 | AUC=0.976
#    📊 HOIC - CE Loss=0.0039 | Precision=0.987 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 24/60
#    🏋️ Training: Total Loss=0.4166 | CE Loss=0.0389 | Rec Loss=0.4981 | MI Loss=3.2793
#    🔬 Kernel Bandwidths: s_x=8.5224 | s_y=8.3895
#    📊 SOLARIS - CE Loss=0.0187 | Precision=0.333 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0401 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0037 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0059 | Precision=0.985 | Recall=0.670 | Accuracy=0.999 | AUC=0.835
#    📊 RARE - CE Loss=0.0076 | Precision=0.974 | Recall=0.500 | Accuracy=0.998 | AUC=0.750
#    📊 SLOWHTTPS - CE Loss=0.0073 | Precision=0.991 | Recall=0.603 | Accuracy=0.997 | AUC=0.801
#    📊 HOIC - CE Loss=0.0041 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 27/60
#    🏋️ Training: Total Loss=0.4146 | CE Loss=0.0400 | Rec Loss=0.4937 | MI Loss=3.2532
#    🔬 Kernel Bandwidths: s_x=8.5900 | s_y=8.4493
#    📊 SOLARIS - CE Loss=0.0211 | Precision=0.994 | Recall=0.650 | Accuracy=0.996 | AUC=0.825
#    📊 INFIL - CE Loss=0.0393 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0034 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0050 | Precision=0.986 | Recall=0.710 | Accuracy=0.999 | AUC=0.855
#    📊 RARE - CE Loss=0.0076 | Precision=0.976 | Recall=0.553 | Accuracy=0.999 | AUC=0.777
#    📊 SLOWHTTPS - CE Loss=0.0039 | Precision=0.995 | Recall=0.987 | Accuracy=1.000 | AUC=0.993
#    📊 HOIC - CE Loss=0.0034 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 30/60
#    🏋️ Training: Total Loss=0.4140 | CE Loss=0.0405 | Rec Loss=0.4889 | MI Loss=3.2457
#    🔬 Kernel Bandwidths: s_x=8.6582 | s_y=8.5110
#    📊 SOLARIS - CE Loss=0.0232 | Precision=0.994 | Recall=0.658 | Accuracy=0.997 | AUC=0.829
#    📊 INFIL - CE Loss=0.0432 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0020 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0033 | Precision=0.987 | Recall=0.755 | Accuracy=0.999 | AUC=0.877
#    📊 RARE - CE Loss=0.0072 | Precision=0.953 | Recall=0.273 | Accuracy=0.998 | AUC=0.637
#    📊 SLOWHTTPS - CE Loss=0.0020 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0019 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 33/60
#    🏋️ Training: Total Loss=0.4052 | CE Loss=0.0340 | Rec Loss=0.4787 | MI Loss=3.2335
#    🔬 Kernel Bandwidths: s_x=8.7268 | s_y=8.5730
#    📊 SOLARIS - CE Loss=0.0284 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0400 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0032 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0057 | Precision=0.983 | Recall=0.580 | Accuracy=0.998 | AUC=0.790
#    📊 RARE - CE Loss=0.0074 | Precision=0.962 | Recall=0.333 | Accuracy=0.998 | AUC=0.667
#    📊 SLOWHTTPS - CE Loss=0.0045 | Precision=0.994 | Recall=0.851 | Accuracy=0.999 | AUC=0.925
#    📊 HOIC - CE Loss=0.0030 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 36/60
#    🏋️ Training: Total Loss=0.4020 | CE Loss=0.0314 | Rec Loss=0.4850 | MI Loss=3.2204
#    🔬 Kernel Bandwidths: s_x=8.7961 | s_y=8.6366
#    📊 SOLARIS - CE Loss=0.0294 | Precision=0.333 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0429 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0019 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0045 | Precision=0.986 | Recall=0.720 | Accuracy=0.999 | AUC=0.860
#    📊 RARE - CE Loss=0.0061 | Precision=0.975 | Recall=0.520 | Accuracy=0.999 | AUC=0.760
#    📊 SLOWHTTPS - CE Loss=0.0024 | Precision=0.995 | Recall=0.992 | Accuracy=1.000 | AUC=0.996
#    📊 HOIC - CE Loss=0.0019 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 39/60
#    🏋️ Training: Total Loss=0.3999 | CE Loss=0.0308 | Rec Loss=0.4824 | MI Loss=3.2090
#    🔬 Kernel Bandwidths: s_x=8.8658 | s_y=8.6996
#    📊 SOLARIS - CE Loss=0.0369 | Precision=0.333 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0453 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0031 | Precision=0.990 | Recall=0.990 | Accuracy=1.000 | AUC=0.995
#    📊 GOLDEN_EYE - CE Loss=0.0064 | Precision=0.971 | Recall=0.340 | Accuracy=0.997 | AUC=0.670
#    📊 RARE - CE Loss=0.0074 | Precision=0.800 | Recall=0.053 | Accuracy=0.997 | AUC=0.527
#    📊 SLOWHTTPS - CE Loss=0.0042 | Precision=0.992 | Recall=0.656 | Accuracy=0.997 | AUC=0.828
#    📊 HOIC - CE Loss=0.0022 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 42/60
#    🏋️ Training: Total Loss=0.3959 | CE Loss=0.0294 | Rec Loss=0.4753 | MI Loss=3.1895
#    🔬 Kernel Bandwidths: s_x=8.9361 | s_y=8.7610
#    📊 SOLARIS - CE Loss=0.0223 | Precision=0.991 | Recall=0.658 | Accuracy=0.997 | AUC=0.829
#    📊 INFIL - CE Loss=0.0436 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0012 | Precision=0.985 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0031 | Precision=0.980 | Recall=0.730 | Accuracy=0.999 | AUC=0.865
#    📊 RARE - CE Loss=0.0048 | Precision=0.965 | Recall=0.547 | Accuracy=0.999 | AUC=0.773
#    📊 SLOWHTTPS - CE Loss=0.0021 | Precision=0.992 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 HOIC - CE Loss=0.0013 | Precision=0.992 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 45/60
#    🏋️ Training: Total Loss=0.3938 | CE Loss=0.0277 | Rec Loss=0.4810 | MI Loss=3.1804
#    🔬 Kernel Bandwidths: s_x=9.0069 | s_y=8.8225
#    📊 SOLARIS - CE Loss=0.0264 | Precision=0.250 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0512 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0009 | Precision=0.985 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0041 | Precision=0.979 | Recall=0.690 | Accuracy=0.999 | AUC=0.845
#    📊 RARE - CE Loss=0.0056 | Precision=0.963 | Recall=0.527 | Accuracy=0.999 | AUC=0.763
#    📊 SLOWHTTPS - CE Loss=0.0024 | Precision=0.992 | Recall=0.952 | Accuracy=1.000 | AUC=0.976
#    📊 HOIC - CE Loss=0.0008 | Precision=0.992 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 48/60
#    🏋️ Training: Total Loss=0.3951 | CE Loss=0.0313 | Rec Loss=0.4632 | MI Loss=3.1747
#    🔬 Kernel Bandwidths: s_x=9.0783 | s_y=8.8836
#    📊 SOLARIS - CE Loss=0.0238 | Precision=0.994 | Recall=0.660 | Accuracy=0.997 | AUC=0.830
#    📊 INFIL - CE Loss=0.0459 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0009 | Precision=0.990 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0019 | Precision=0.989 | Recall=0.895 | Accuracy=1.000 | AUC=0.947
#    📊 RARE - CE Loss=0.0050 | Precision=0.975 | Recall=0.527 | Accuracy=0.999 | AUC=0.763
#    📊 SLOWHTTPS - CE Loss=0.0011 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0009 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 51/60
#    🏋️ Training: Total Loss=0.3871 | CE Loss=0.0258 | Rec Loss=0.4587 | MI Loss=3.1543
#    🔬 Kernel Bandwidths: s_x=9.1502 | s_y=8.9490
#    📊 SOLARIS - CE Loss=0.0241 | Precision=0.994 | Recall=0.662 | Accuracy=0.997 | AUC=0.831
#    📊 INFIL - CE Loss=0.0475 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0008 | Precision=0.990 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0020 | Precision=0.988 | Recall=0.805 | Accuracy=0.999 | AUC=0.902
#    📊 RARE - CE Loss=0.0040 | Precision=0.980 | Recall=0.647 | Accuracy=0.999 | AUC=0.823
#    📊 SLOWHTTPS - CE Loss=0.0009 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0008 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 54/60
#    🏋️ Training: Total Loss=0.3877 | CE Loss=0.0271 | Rec Loss=0.4580 | MI Loss=3.1478
#    🔬 Kernel Bandwidths: s_x=9.2227 | s_y=9.0131
#    📊 SOLARIS - CE Loss=0.0225 | Precision=0.994 | Recall=0.660 | Accuracy=0.997 | AUC=0.830
#    📊 INFIL - CE Loss=0.0461 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0010 | Precision=0.990 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0018 | Precision=0.989 | Recall=0.915 | Accuracy=1.000 | AUC=0.957
#    📊 RARE - CE Loss=0.0051 | Precision=0.976 | Recall=0.553 | Accuracy=0.999 | AUC=0.777
#    📊 SLOWHTTPS - CE Loss=0.0010 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0010 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 57/60
#    🏋️ Training: Total Loss=0.3898 | CE Loss=0.0294 | Rec Loss=0.4652 | MI Loss=3.1392
#    🔬 Kernel Bandwidths: s_x=9.2958 | s_y=9.0773
#    📊 SOLARIS - CE Loss=0.0314 | Precision=0.500 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0425 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0016 | Precision=0.995 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0045 | Precision=0.993 | Recall=0.670 | Accuracy=0.999 | AUC=0.835
#    📊 RARE - CE Loss=0.0054 | Precision=0.988 | Recall=0.553 | Accuracy=0.999 | AUC=0.777
#    📊 SLOWHTTPS - CE Loss=0.0023 | Precision=0.997 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0020 | Precision=0.997 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 60/60
#    🏋️ Training: Total Loss=0.3880 | CE Loss=0.0296 | Rec Loss=0.4544 | MI Loss=3.1297
#    🔬 Kernel Bandwidths: s_x=9.3694 | s_y=9.1433
#    📊 SOLARIS - CE Loss=0.0306 | Precision=0.997 | Recall=0.658 | Accuracy=0.997 | AUC=0.829
#    📊 INFIL - CE Loss=0.0526 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0007 | Precision=0.995 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0029 | Precision=0.993 | Recall=0.670 | Accuracy=0.999 | AUC=0.835
#    📊 RARE - CE Loss=0.0067 | Precision=0.985 | Recall=0.427 | Accuracy=0.998 | AUC=0.713
#    📊 SLOWHTTPS - CE Loss=0.0015 | Precision=0.997 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 HOIC - CE Loss=0.0006 | Precision=0.997 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#   [New Best AUC: 0.8393 at (λ_mse=0.100, λ_mi=0.100)]
# ✅ Best model saved to: best_model_lambda_mse_0.100_lambda_mi_0.100.pth
# ================================================================================
# 🔍 Hyperparameter Search: λ_mse=0.500, λ_mi=0.500
# ================================================================================
# 📌 Epoch 3/60
#    🏋️ Training: Total Loss=2.0930 | CE Loss=0.2108 | Rec Loss=0.6342 | MI Loss=3.1302
#    🔬 Kernel Bandwidths: s_x=9.4441 | s_y=9.1818
#    📊 SOLARIS - CE Loss=0.0903 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0824 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0754 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0759 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0736 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0842 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0841 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 6/60
#    🏋️ Training: Total Loss=1.9925 | CE Loss=0.2072 | Rec Loss=0.4872 | MI Loss=3.0833
#    🔬 Kernel Bandwidths: s_x=9.5189 | s_y=9.1935
#    📊 SOLARIS - CE Loss=0.0825 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0741 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0666 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0671 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0650 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0755 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0757 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 9/60
#    🏋️ Training: Total Loss=1.9608 | CE Loss=0.2049 | Rec Loss=0.4385 | MI Loss=3.0734
#    🔬 Kernel Bandwidths: s_x=9.5942 | s_y=9.2054
#    📊 SOLARIS - CE Loss=0.0798 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0717 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0635 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0642 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0622 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0727 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0729 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 12/60
#    🏋️ Training: Total Loss=1.9483 | CE Loss=0.1926 | Rec Loss=0.4373 | MI Loss=3.0740
#    🔬 Kernel Bandwidths: s_x=9.6701 | s_y=9.2256
#    📊 SOLARIS - CE Loss=0.0756 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0689 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0585 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0600 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0585 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0681 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0683 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 15/60
#    🏋️ Training: Total Loss=1.9004 | CE Loss=0.1446 | Rec Loss=0.4352 | MI Loss=3.0764
#    🔬 Kernel Bandwidths: s_x=9.7466 | s_y=9.2771
#    📊 SOLARIS - CE Loss=0.0545 | Precision=1.000 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0500 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0336 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0366 | Precision=1.000 | Recall=0.015 | Accuracy=0.996 | AUC=0.507
#    📊 RARE - CE Loss=0.0366 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0418 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0421 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 18/60
#    🏋️ Training: Total Loss=1.8761 | CE Loss=0.1294 | Rec Loss=0.4235 | MI Loss=3.0698
#    🔬 Kernel Bandwidths: s_x=9.8238 | s_y=9.3421
#    📊 SOLARIS - CE Loss=0.0529 | Precision=1.000 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0515 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0310 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0360 | Precision=1.000 | Recall=0.320 | Accuracy=0.997 | AUC=0.660
#    📊 RARE - CE Loss=0.0364 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0394 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0400 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 21/60
#    🏋️ Training: Total Loss=1.8608 | CE Loss=0.1159 | Rec Loss=0.4203 | MI Loss=3.0696
#    🔬 Kernel Bandwidths: s_x=9.9016 | s_y=9.4103
#    📊 SOLARIS - CE Loss=0.0450 | Precision=1.000 | Recall=0.002 | Accuracy=0.990 | AUC=0.501
#    📊 INFIL - CE Loss=0.0457 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0225 | Precision=1.000 | Recall=0.990 | Accuracy=1.000 | AUC=0.995
#    📊 GOLDEN_EYE - CE Loss=0.0280 | Precision=1.000 | Recall=0.330 | Accuracy=0.997 | AUC=0.665
#    📊 RARE - CE Loss=0.0290 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0308 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0321 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 24/60
#    🏋️ Training: Total Loss=1.8446 | CE Loss=0.1031 | Rec Loss=0.4187 | MI Loss=3.0643
#    🔬 Kernel Bandwidths: s_x=9.9800 | s_y=9.4801
#    📊 SOLARIS - CE Loss=0.0396 | Precision=1.000 | Recall=0.004 | Accuracy=0.990 | AUC=0.502
#    📊 INFIL - CE Loss=0.0446 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0202 | Precision=1.000 | Recall=0.990 | Accuracy=1.000 | AUC=0.995
#    📊 GOLDEN_EYE - CE Loss=0.0239 | Precision=1.000 | Recall=0.340 | Accuracy=0.997 | AUC=0.670
#    📊 RARE - CE Loss=0.0268 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0272 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0297 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 27/60
#    🏋️ Training: Total Loss=1.8333 | CE Loss=0.0974 | Rec Loss=0.4201 | MI Loss=3.0518
#    🔬 Kernel Bandwidths: s_x=10.0591 | s_y=9.5482
#    📊 SOLARIS - CE Loss=0.0305 | Precision=0.750 | Recall=0.006 | Accuracy=0.990 | AUC=0.503
#    📊 INFIL - CE Loss=0.0430 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0175 | Precision=0.989 | Recall=0.455 | Accuracy=0.998 | AUC=0.727
#    📊 GOLDEN_EYE - CE Loss=0.0199 | Precision=0.987 | Recall=0.385 | Accuracy=0.998 | AUC=0.692
#    📊 RARE - CE Loss=0.0236 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0234 | Precision=0.995 | Recall=0.507 | Accuracy=0.996 | AUC=0.753
#    📊 HOIC - CE Loss=0.0265 | Precision=0.995 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 30/60
#    🏋️ Training: Total Loss=1.8150 | CE Loss=0.0897 | Rec Loss=0.4079 | MI Loss=3.0427
#    🔬 Kernel Bandwidths: s_x=10.1388 | s_y=9.6162
#    📊 SOLARIS - CE Loss=0.0349 | Precision=1.000 | Recall=0.010 | Accuracy=0.990 | AUC=0.505
#    📊 INFIL - CE Loss=0.0421 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0190 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0226 | Precision=1.000 | Recall=0.325 | Accuracy=0.997 | AUC=0.662
#    📊 RARE - CE Loss=0.0253 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0267 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0279 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 33/60
#    🏋️ Training: Total Loss=1.8021 | CE Loss=0.0815 | Rec Loss=0.4073 | MI Loss=3.0339
#    🔬 Kernel Bandwidths: s_x=10.2191 | s_y=9.6827
#    📊 SOLARIS - CE Loss=0.0286 | Precision=1.000 | Recall=0.010 | Accuracy=0.990 | AUC=0.505
#    📊 INFIL - CE Loss=0.0421 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0169 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0199 | Precision=1.000 | Recall=0.645 | Accuracy=0.999 | AUC=0.823
#    📊 RARE - CE Loss=0.0225 | Precision=1.000 | Recall=0.120 | Accuracy=0.997 | AUC=0.560
#    📊 SLOWHTTPS - CE Loss=0.0255 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0273 | Precision=1.000 | Recall=0.517 | Accuracy=0.996 | AUC=0.759
# 📌 Epoch 36/60
#    🏋️ Training: Total Loss=1.7984 | CE Loss=0.0853 | Rec Loss=0.3979 | MI Loss=3.0281
#    🔬 Kernel Bandwidths: s_x=10.3001 | s_y=9.7495
#    📊 SOLARIS - CE Loss=0.0215 | Precision=1.000 | Recall=0.670 | Accuracy=0.997 | AUC=0.835
#    📊 INFIL - CE Loss=0.0405 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0124 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0151 | Precision=1.000 | Recall=0.645 | Accuracy=0.999 | AUC=0.823
#    📊 RARE - CE Loss=0.0185 | Precision=1.000 | Recall=0.213 | Accuracy=0.998 | AUC=0.607
#    📊 SLOWHTTPS - CE Loss=0.0225 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0232 | Precision=1.000 | Recall=0.533 | Accuracy=0.997 | AUC=0.767
# 📌 Epoch 39/60
#    🏋️ Training: Total Loss=1.7888 | CE Loss=0.0794 | Rec Loss=0.3964 | MI Loss=3.0224
#    🔬 Kernel Bandwidths: s_x=10.3817 | s_y=9.8189
#    📊 SOLARIS - CE Loss=0.0191 | Precision=1.000 | Recall=0.024 | Accuracy=0.990 | AUC=0.512
#    📊 INFIL - CE Loss=0.0407 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0108 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0132 | Precision=1.000 | Recall=0.585 | Accuracy=0.998 | AUC=0.792
#    📊 RARE - CE Loss=0.0170 | Precision=1.000 | Recall=0.113 | Accuracy=0.997 | AUC=0.557
#    📊 SLOWHTTPS - CE Loss=0.0206 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0212 | Precision=1.000 | Recall=0.536 | Accuracy=0.997 | AUC=0.768
# 📌 Epoch 42/60
#    🏋️ Training: Total Loss=1.7826 | CE Loss=0.0830 | Rec Loss=0.3941 | MI Loss=3.0052
#    🔬 Kernel Bandwidths: s_x=10.4639 | s_y=9.8877
#    📊 SOLARIS - CE Loss=0.0182 | Precision=1.000 | Recall=0.998 | Accuracy=1.000 | AUC=0.999
#    📊 INFIL - CE Loss=0.0410 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0134 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0153 | Precision=1.000 | Recall=0.690 | Accuracy=0.999 | AUC=0.845
#    📊 RARE - CE Loss=0.0183 | Precision=1.000 | Recall=0.247 | Accuracy=0.998 | AUC=0.623
#    📊 SLOWHTTPS - CE Loss=0.0228 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0227 | Precision=1.000 | Recall=0.536 | Accuracy=0.997 | AUC=0.768
# 📌 Epoch 45/60
#    🏋️ Training: Total Loss=1.7806 | CE Loss=0.0766 | Rec Loss=0.3979 | MI Loss=3.0101
#    🔬 Kernel Bandwidths: s_x=10.5468 | s_y=9.9579
#    📊 SOLARIS - CE Loss=0.0226 | Precision=1.000 | Recall=0.028 | Accuracy=0.990 | AUC=0.514
#    📊 INFIL - CE Loss=0.0408 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0141 | Precision=1.000 | Recall=0.990 | Accuracy=1.000 | AUC=0.995
#    📊 GOLDEN_EYE - CE Loss=0.0164 | Precision=1.000 | Recall=0.550 | Accuracy=0.998 | AUC=0.775
#    📊 RARE - CE Loss=0.0198 | Precision=1.000 | Recall=0.047 | Accuracy=0.997 | AUC=0.523
#    📊 SLOWHTTPS - CE Loss=0.0228 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0231 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 48/60
#    🏋️ Training: Total Loss=1.7703 | CE Loss=0.0740 | Rec Loss=0.3950 | MI Loss=2.9978
#    🔬 Kernel Bandwidths: s_x=10.6304 | s_y=10.0311
#    📊 SOLARIS - CE Loss=0.0204 | Precision=1.000 | Recall=0.646 | Accuracy=0.996 | AUC=0.823
#    📊 INFIL - CE Loss=0.0406 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0126 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0147 | Precision=1.000 | Recall=0.575 | Accuracy=0.998 | AUC=0.787
#    📊 RARE - CE Loss=0.0192 | Precision=1.000 | Recall=0.147 | Accuracy=0.997 | AUC=0.573
#    📊 SLOWHTTPS - CE Loss=0.0220 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0214 | Precision=1.000 | Recall=0.533 | Accuracy=0.997 | AUC=0.767
# 📌 Epoch 51/60
#    🏋️ Training: Total Loss=1.7602 | CE Loss=0.0702 | Rec Loss=0.3905 | MI Loss=2.9895
#    🔬 Kernel Bandwidths: s_x=10.7146 | s_y=10.1052
#    📊 SOLARIS - CE Loss=0.0164 | Precision=1.000 | Recall=0.340 | Accuracy=0.993 | AUC=0.670
#    📊 INFIL - CE Loss=0.0385 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0086 | Precision=1.000 | Recall=0.990 | Accuracy=1.000 | AUC=0.995
#    📊 GOLDEN_EYE - CE Loss=0.0111 | Precision=1.000 | Recall=0.555 | Accuracy=0.998 | AUC=0.778
#    📊 RARE - CE Loss=0.0146 | Precision=1.000 | Recall=0.047 | Accuracy=0.997 | AUC=0.523
#    📊 SLOWHTTPS - CE Loss=0.0168 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0165 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 54/60
#    🏋️ Training: Total Loss=1.7511 | CE Loss=0.0688 | Rec Loss=0.3848 | MI Loss=2.9799
#    🔬 Kernel Bandwidths: s_x=10.7994 | s_y=10.1793
#    📊 SOLARIS - CE Loss=0.0136 | Precision=0.997 | Recall=0.672 | Accuracy=0.997 | AUC=0.836
#    📊 INFIL - CE Loss=0.0386 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0064 | Precision=0.995 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0084 | Precision=0.992 | Recall=0.640 | Accuracy=0.999 | AUC=0.820
#    📊 RARE - CE Loss=0.0117 | Precision=0.977 | Recall=0.280 | Accuracy=0.998 | AUC=0.640
#    📊 SLOWHTTPS - CE Loss=0.0166 | Precision=0.995 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0146 | Precision=0.995 | Recall=0.536 | Accuracy=0.997 | AUC=0.768
# 📌 Epoch 57/60
#    🏋️ Training: Total Loss=1.7467 | CE Loss=0.0657 | Rec Loss=0.3948 | MI Loss=2.9672
#    🔬 Kernel Bandwidths: s_x=10.8848 | s_y=10.2516
#    📊 SOLARIS - CE Loss=0.0239 | Precision=1.000 | Recall=0.018 | Accuracy=0.990 | AUC=0.509
#    📊 INFIL - CE Loss=0.0371 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0115 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0137 | Precision=1.000 | Recall=0.340 | Accuracy=0.997 | AUC=0.670
#    📊 RARE - CE Loss=0.0161 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0189 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0171 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 60/60
#    🏋️ Training: Total Loss=1.7321 | CE Loss=0.0644 | Rec Loss=0.3771 | MI Loss=2.9585
#    🔬 Kernel Bandwidths: s_x=10.9711 | s_y=10.3276
#    📊 SOLARIS - CE Loss=0.0155 | Precision=1.000 | Recall=0.674 | Accuracy=0.997 | AUC=0.837
#    📊 INFIL - CE Loss=0.0387 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0086 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0108 | Precision=1.000 | Recall=0.635 | Accuracy=0.999 | AUC=0.818
#    📊 RARE - CE Loss=0.0136 | Precision=1.000 | Recall=0.500 | Accuracy=0.998 | AUC=0.750
#    📊 SLOWHTTPS - CE Loss=0.0173 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0157 | Precision=1.000 | Recall=0.536 | Accuracy=0.997 | AUC=0.768
# ================================================================================
# 🔍 Hyperparameter Search: λ_mse=0.100, λ_mi=0.900
# ================================================================================
# 📌 Epoch 3/60
#    🏋️ Training: Total Loss=2.9541 | CE Loss=0.2112 | Rec Loss=0.8108 | MI Loss=2.9576
#    🔬 Kernel Bandwidths: s_x=11.0588 | s_y=10.3570
#    📊 SOLARIS - CE Loss=0.0849 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0761 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0692 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0693 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0671 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0776 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0775 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 6/60
#    🏋️ Training: Total Loss=2.9035 | CE Loss=0.1967 | Rec Loss=0.6222 | MI Loss=2.9384
#    🔬 Kernel Bandwidths: s_x=11.1465 | s_y=10.3658
#    📊 SOLARIS - CE Loss=0.0750 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0654 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0567 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0568 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0554 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0658 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0656 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 9/60
#    🏋️ Training: Total Loss=2.8630 | CE Loss=0.1564 | Rec Loss=0.5728 | MI Loss=2.9437
#    🔬 Kernel Bandwidths: s_x=11.2348 | s_y=10.3895
#    📊 SOLARIS - CE Loss=0.0613 | Precision=1.000 | Recall=0.022 | Accuracy=0.990 | AUC=0.511
#    📊 INFIL - CE Loss=0.0565 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0433 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0430 | Precision=1.000 | Recall=0.175 | Accuracy=0.997 | AUC=0.588
#    📊 RARE - CE Loss=0.0437 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0488 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0494 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 12/60
#    🏋️ Training: Total Loss=2.8319 | CE Loss=0.1341 | Rec Loss=0.5293 | MI Loss=2.9388
#    🔬 Kernel Bandwidths: s_x=11.3238 | s_y=10.4319
#    📊 SOLARIS - CE Loss=0.0579 | Precision=1.000 | Recall=0.014 | Accuracy=0.990 | AUC=0.507
#    📊 INFIL - CE Loss=0.0513 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0363 | Precision=1.000 | Recall=0.060 | Accuracy=0.996 | AUC=0.530
#    📊 GOLDEN_EYE - CE Loss=0.0362 | Precision=1.000 | Recall=0.425 | Accuracy=0.998 | AUC=0.713
#    📊 RARE - CE Loss=0.0378 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0409 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0424 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 15/60
#    🏋️ Training: Total Loss=2.8106 | CE Loss=0.1185 | Rec Loss=0.5208 | MI Loss=2.9333
#    🔬 Kernel Bandwidths: s_x=11.4134 | s_y=10.4888
#    📊 SOLARIS - CE Loss=0.0477 | Precision=1.000 | Recall=0.014 | Accuracy=0.990 | AUC=0.507
#    📊 INFIL - CE Loss=0.0458 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0276 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0278 | Precision=1.000 | Recall=0.505 | Accuracy=0.998 | AUC=0.752
#    📊 RARE - CE Loss=0.0301 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0327 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0332 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 18/60
#    🏋️ Training: Total Loss=2.7800 | CE Loss=0.1004 | Rec Loss=0.5073 | MI Loss=2.9210
#    🔬 Kernel Bandwidths: s_x=11.5038 | s_y=10.5576
#    📊 SOLARIS - CE Loss=0.0425 | Precision=1.000 | Recall=0.022 | Accuracy=0.990 | AUC=0.511
#    📊 INFIL - CE Loss=0.0421 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0213 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0215 | Precision=1.000 | Recall=0.515 | Accuracy=0.998 | AUC=0.758
#    📊 RARE - CE Loss=0.0240 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0266 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0271 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 21/60
#    🏋️ Training: Total Loss=2.7738 | CE Loss=0.0946 | Rec Loss=0.4996 | MI Loss=2.9214
#    🔬 Kernel Bandwidths: s_x=11.5949 | s_y=10.6295
#    📊 SOLARIS - CE Loss=0.0382 | Precision=1.000 | Recall=0.014 | Accuracy=0.990 | AUC=0.507
#    📊 INFIL - CE Loss=0.0420 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0198 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0199 | Precision=1.000 | Recall=0.540 | Accuracy=0.998 | AUC=0.770
#    📊 RARE - CE Loss=0.0226 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0248 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0245 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 24/60
#    🏋️ Training: Total Loss=2.7378 | CE Loss=0.0740 | Rec Loss=0.4946 | MI Loss=2.9048
#    🔬 Kernel Bandwidths: s_x=11.6867 | s_y=10.7049
#    📊 SOLARIS - CE Loss=0.0317 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0390 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0131 | Precision=1.000 | Recall=0.455 | Accuracy=0.998 | AUC=0.728
#    📊 GOLDEN_EYE - CE Loss=0.0141 | Precision=1.000 | Recall=0.550 | Accuracy=0.998 | AUC=0.775
#    📊 RARE - CE Loss=0.0170 | Precision=1.000 | Recall=0.260 | Accuracy=0.998 | AUC=0.630
#    📊 SLOWHTTPS - CE Loss=0.0209 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0200 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 27/60
#    🏋️ Training: Total Loss=2.7290 | CE Loss=0.0665 | Rec Loss=0.4831 | MI Loss=2.9047
#    🔬 Kernel Bandwidths: s_x=11.7792 | s_y=10.7775
#    📊 SOLARIS - CE Loss=0.0222 | Precision=0.994 | Recall=0.656 | Accuracy=0.997 | AUC=0.828
#    📊 INFIL - CE Loss=0.0391 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0097 | Precision=0.990 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0112 | Precision=0.982 | Recall=0.555 | Accuracy=0.998 | AUC=0.777
#    📊 RARE - CE Loss=0.0137 | Precision=0.951 | Recall=0.260 | Accuracy=0.998 | AUC=0.630
#    📊 SLOWHTTPS - CE Loss=0.0178 | Precision=0.989 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0174 | Precision=0.990 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 30/60
#    🏋️ Training: Total Loss=2.7131 | CE Loss=0.0653 | Rec Loss=0.4729 | MI Loss=2.8895
#    🔬 Kernel Bandwidths: s_x=11.8724 | s_y=10.8484
#    📊 SOLARIS - CE Loss=0.0212 | Precision=0.997 | Recall=0.636 | Accuracy=0.996 | AUC=0.818
#    📊 INFIL - CE Loss=0.0393 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0095 | Precision=0.995 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0111 | Precision=0.993 | Recall=0.665 | Accuracy=0.999 | AUC=0.832
#    📊 RARE - CE Loss=0.0134 | Precision=0.984 | Recall=0.407 | Accuracy=0.998 | AUC=0.703
#    📊 SLOWHTTPS - CE Loss=0.0177 | Precision=0.995 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0175 | Precision=0.995 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 33/60
#    🏋️ Training: Total Loss=2.6998 | CE Loss=0.0574 | Rec Loss=0.4693 | MI Loss=2.8838
#    🔬 Kernel Bandwidths: s_x=11.9664 | s_y=10.9213
#    📊 SOLARIS - CE Loss=0.0217 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0390 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0056 | Precision=0.990 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0074 | Precision=0.983 | Recall=0.570 | Accuracy=0.998 | AUC=0.785
#    📊 RARE - CE Loss=0.0098 | Precision=0.833 | Recall=0.067 | Accuracy=0.997 | AUC=0.533
#    📊 SLOWHTTPS - CE Loss=0.0133 | Precision=0.989 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0129 | Precision=0.990 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 36/60
#    🏋️ Training: Total Loss=2.6853 | CE Loss=0.0519 | Rec Loss=0.4717 | MI Loss=2.8735
#    🔬 Kernel Bandwidths: s_x=12.0612 | s_y=10.9944
#    📊 SOLARIS - CE Loss=0.0173 | Precision=0.992 | Recall=0.478 | Accuracy=0.995 | AUC=0.739
#    📊 INFIL - CE Loss=0.0392 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0041 | Precision=0.990 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0060 | Precision=0.985 | Recall=0.665 | Accuracy=0.999 | AUC=0.832
#    📊 RARE - CE Loss=0.0090 | Precision=0.951 | Recall=0.260 | Accuracy=0.998 | AUC=0.630
#    📊 SLOWHTTPS - CE Loss=0.0122 | Precision=0.989 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0115 | Precision=0.990 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 39/60
#    🏋️ Training: Total Loss=2.6801 | CE Loss=0.0477 | Rec Loss=0.4653 | MI Loss=2.8732
#    🔬 Kernel Bandwidths: s_x=12.1567 | s_y=11.0677
#    📊 SOLARIS - CE Loss=0.0143 | Precision=1.000 | Recall=0.656 | Accuracy=0.997 | AUC=0.828
#    📊 INFIL - CE Loss=0.0393 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0046 | Precision=1.000 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0065 | Precision=1.000 | Recall=0.670 | Accuracy=0.999 | AUC=0.835
#    📊 RARE - CE Loss=0.0085 | Precision=1.000 | Recall=0.407 | Accuracy=0.998 | AUC=0.703
#    📊 SLOWHTTPS - CE Loss=0.0115 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0113 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 42/60
#    🏋️ Training: Total Loss=2.6742 | CE Loss=0.0489 | Rec Loss=0.4735 | MI Loss=2.8644
#    🔬 Kernel Bandwidths: s_x=12.2528 | s_y=11.1426
#    📊 SOLARIS - CE Loss=0.0140 | Precision=0.997 | Recall=0.626 | Accuracy=0.996 | AUC=0.813
#    📊 INFIL - CE Loss=0.0426 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0027 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0049 | Precision=0.992 | Recall=0.655 | Accuracy=0.999 | AUC=0.827
#    📊 RARE - CE Loss=0.0075 | Precision=0.987 | Recall=0.493 | Accuracy=0.998 | AUC=0.747
#    📊 SLOWHTTPS - CE Loss=0.0087 | Precision=0.995 | Recall=0.504 | Accuracy=0.996 | AUC=0.752
#    📊 HOIC - CE Loss=0.0102 | Precision=0.995 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 45/60
#    🏋️ Training: Total Loss=2.6591 | CE Loss=0.0454 | Rec Loss=0.4712 | MI Loss=2.8518
#    🔬 Kernel Bandwidths: s_x=12.3497 | s_y=11.2192
#    📊 SOLARIS - CE Loss=0.0158 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0395 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0036 | Precision=1.000 | Recall=0.995 | Accuracy=1.000 | AUC=0.998
#    📊 GOLDEN_EYE - CE Loss=0.0055 | Precision=1.000 | Recall=0.660 | Accuracy=0.999 | AUC=0.830
#    📊 RARE - CE Loss=0.0076 | Precision=1.000 | Recall=0.493 | Accuracy=0.998 | AUC=0.747
#    📊 SLOWHTTPS - CE Loss=0.0085 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0100 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 48/60
#    🏋️ Training: Total Loss=2.6550 | CE Loss=0.0506 | Rec Loss=0.4708 | MI Loss=2.8416
#    🔬 Kernel Bandwidths: s_x=12.4475 | s_y=11.2974
#    📊 SOLARIS - CE Loss=0.0124 | Precision=1.000 | Recall=0.656 | Accuracy=0.997 | AUC=0.828
#    📊 INFIL - CE Loss=0.0398 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0033 | Precision=1.000 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0047 | Precision=1.000 | Recall=0.720 | Accuracy=0.999 | AUC=0.860
#    📊 RARE - CE Loss=0.0080 | Precision=1.000 | Recall=0.493 | Accuracy=0.998 | AUC=0.747
#    📊 SLOWHTTPS - CE Loss=0.0069 | Precision=1.000 | Recall=0.507 | Accuracy=0.996 | AUC=0.753
#    📊 HOIC - CE Loss=0.0085 | Precision=1.000 | Recall=0.517 | Accuracy=0.996 | AUC=0.759
# 📌 Epoch 51/60
#    🏋️ Training: Total Loss=2.6376 | CE Loss=0.0400 | Rec Loss=0.4652 | MI Loss=2.8345
#    🔬 Kernel Bandwidths: s_x=12.5461 | s_y=11.3785
#    📊 SOLARIS - CE Loss=0.0153 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0427 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0020 | Precision=1.000 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0040 | Precision=1.000 | Recall=0.660 | Accuracy=0.999 | AUC=0.830
#    📊 RARE - CE Loss=0.0063 | Precision=1.000 | Recall=0.493 | Accuracy=0.998 | AUC=0.747
#    📊 SLOWHTTPS - CE Loss=0.0067 | Precision=1.000 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0077 | Precision=1.000 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 54/60
#    🏋️ Training: Total Loss=2.6355 | CE Loss=0.0411 | Rec Loss=0.4629 | MI Loss=2.8312
#    🔬 Kernel Bandwidths: s_x=12.6455 | s_y=11.4607
#    📊 SOLARIS - CE Loss=0.0133 | Precision=0.997 | Recall=0.656 | Accuracy=0.997 | AUC=0.828
#    📊 INFIL - CE Loss=0.0403 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0026 | Precision=0.995 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
#    📊 GOLDEN_EYE - CE Loss=0.0041 | Precision=0.993 | Recall=0.725 | Accuracy=0.999 | AUC=0.862
#    📊 RARE - CE Loss=0.0067 | Precision=0.987 | Recall=0.493 | Accuracy=0.998 | AUC=0.747
#    📊 SLOWHTTPS - CE Loss=0.0055 | Precision=0.996 | Recall=0.611 | Accuracy=0.997 | AUC=0.805
# ...
# 📌 Epoch 3/60
#    🏋️ Training: Total Loss=0.7705 | CE Loss=0.2079 | Rec Loss=0.5424 | MI Loss=2.5593
#    🔬 Kernel Bandwidths: s_x=28.4614 | s_y=20.9288
#    📊 SOLARIS - CE Loss=0.0825 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0757 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0638 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0672 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0653 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0740 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0741 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 6/60
#    🏋️ Training: Total Loss=0.6732 | CE Loss=0.1794 | Rec Loss=0.4731 | MI Loss=2.5387
#    🔬 Kernel Bandwidths: s_x=28.6851 | s_y=21.0880
#    📊 SOLARIS - CE Loss=0.0661 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0556 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0406 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 GOLDEN_EYE - CE Loss=0.0438 | Precision=0.000 | Recall=0.000 | Accuracy=0.996 | AUC=0.500
#    📊 RARE - CE Loss=0.0436 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0483 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
#    📊 HOIC - CE Loss=0.0488 | Precision=0.000 | Recall=0.000 | Accuracy=0.993 | AUC=0.500
# 📌 Epoch 9/60
#    🏋️ Training: Total Loss=0.6070 | CE Loss=0.1345 | Rec Loss=0.4506 | MI Loss=2.6395
#    🔬 Kernel Bandwidths: s_x=28.9114 | s_y=21.2715
#    📊 SOLARIS - CE Loss=0.0710 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0445 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0208 | Precision=0.910 | Recall=0.455 | Accuracy=0.998 | AUC=0.727
#    📊 GOLDEN_EYE - CE Loss=0.0241 | Precision=0.640 | Recall=0.080 | Accuracy=0.996 | AUC=0.540
#    📊 RARE - CE Loss=0.0297 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0296 | Precision=0.000 | Recall=0.000 | Accuracy=0.992 | AUC=0.500
#    📊 HOIC - CE Loss=0.0284 | Precision=0.000 | Recall=0.000 | Accuracy=0.992 | AUC=0.500
# 📌 Epoch 12/60
#    🏋️ Training: Total Loss=0.5733 | CE Loss=0.1000 | Rec Loss=0.4506 | MI Loss=2.7259
#    🔬 Kernel Bandwidths: s_x=29.1392 | s_y=21.4694
#    📊 SOLARIS - CE Loss=0.0877 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0439 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0101 | Precision=0.926 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0125 | Precision=0.893 | Recall=0.665 | Accuracy=0.998 | AUC=0.832
#    📊 RARE - CE Loss=0.0210 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0157 | Precision=0.921 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0151 | Precision=0.923 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 15/60
#    🏋️ Training: Total Loss=0.5553 | CE Loss=0.0917 | Rec Loss=0.4409 | MI Loss=2.7163
#    🔬 Kernel Bandwidths: s_x=29.3691 | s_y=21.6553
#    📊 SOLARIS - CE Loss=0.1017 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0387 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0075 | Precision=0.858 | Recall=0.455 | Accuracy=0.998 | AUC=0.727
#    📊 GOLDEN_EYE - CE Loss=0.0099 | Precision=0.891 | Recall=0.610 | Accuracy=0.998 | AUC=0.805
#    📊 RARE - CE Loss=0.0173 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0140 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0128 | Precision=0.928 | Recall=0.512 | Accuracy=0.996 | AUC=0.756
# 📌 Epoch 18/60
#    🏋️ Training: Total Loss=0.5357 | CE Loss=0.0813 | Rec Loss=0.4317 | MI Loss=2.6987
#    🔬 Kernel Bandwidths: s_x=29.6023 | s_y=21.8328
#    📊 SOLARIS - CE Loss=0.1120 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0497 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0050 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0072 | Precision=0.901 | Recall=0.685 | Accuracy=0.998 | AUC=0.842
#    📊 RARE - CE Loss=0.0161 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0106 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0098 | Precision=0.928 | Recall=0.517 | Accuracy=0.996 | AUC=0.759
# 📌 Epoch 21/60
#    🏋️ Training: Total Loss=0.5253 | CE Loss=0.0768 | Rec Loss=0.4262 | MI Loss=2.6580
#    🔬 Kernel Bandwidths: s_x=29.8371 | s_y=22.0063
#    📊 SOLARIS - CE Loss=0.1166 | Precision=0.953 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0442 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0053 | Precision=0.926 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0070 | Precision=0.916 | Recall=0.870 | Accuracy=0.999 | AUC=0.935
#    📊 RARE - CE Loss=0.0144 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0114 | Precision=0.922 | Recall=0.501 | Accuracy=0.996 | AUC=0.751
#    📊 HOIC - CE Loss=0.0089 | Precision=0.926 | Recall=0.531 | Accuracy=0.996 | AUC=0.765
# 📌 Epoch 24/60
#    🏋️ Training: Total Loss=0.5203 | CE Loss=0.0745 | Rec Loss=0.4238 | MI Loss=2.6254
#    🔬 Kernel Bandwidths: s_x=30.0742 | s_y=22.1783
#    📊 SOLARIS - CE Loss=0.1332 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0482 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0049 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0066 | Precision=0.902 | Recall=0.690 | Accuracy=0.998 | AUC=0.845
#    📊 RARE - CE Loss=0.0144 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0136 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0096 | Precision=0.929 | Recall=0.520 | Accuracy=0.996 | AUC=0.760
# 📌 Epoch 27/60
#    🏋️ Training: Total Loss=0.5118 | CE Loss=0.0691 | Rec Loss=0.4210 | MI Loss=2.5914
#    🔬 Kernel Bandwidths: s_x=30.3131 | s_y=22.3484
#    📊 SOLARIS - CE Loss=0.1405 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0569 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0033 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0045 | Precision=0.922 | Recall=0.890 | Accuracy=0.999 | AUC=0.945
#    📊 RARE - CE Loss=0.0145 | Precision=0.318 | Recall=0.047 | Accuracy=0.997 | AUC=0.523
#    📊 SLOWHTTPS - CE Loss=0.0116 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0072 | Precision=0.931 | Recall=0.536 | Accuracy=0.996 | AUC=0.768
# 📌 Epoch 30/60
#    🏋️ Training: Total Loss=0.5084 | CE Loss=0.0738 | Rec Loss=0.4131 | MI Loss=2.5669
#    🔬 Kernel Bandwidths: s_x=30.5535 | s_y=22.5199
#    📊 SOLARIS - CE Loss=0.1241 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0550 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0029 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0043 | Precision=0.922 | Recall=0.890 | Accuracy=0.999 | AUC=0.945
#    📊 RARE - CE Loss=0.0115 | Precision=0.545 | Recall=0.120 | Accuracy=0.997 | AUC=0.560
#    📊 SLOWHTTPS - CE Loss=0.0172 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0083 | Precision=0.930 | Recall=0.533 | Accuracy=0.996 | AUC=0.767
# 📌 Epoch 33/60
#    🏋️ Training: Total Loss=0.5096 | CE Loss=0.0787 | Rec Loss=0.4097 | MI Loss=2.5278
#    🔬 Kernel Bandwidths: s_x=30.7958 | s_y=22.6893
#    📊 SOLARIS - CE Loss=0.1422 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0565 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0029 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0039 | Precision=0.923 | Recall=0.895 | Accuracy=0.999 | AUC=0.947
#    📊 RARE - CE Loss=0.0130 | Precision=0.348 | Recall=0.053 | Accuracy=0.997 | AUC=0.527
#    📊 SLOWHTTPS - CE Loss=0.0171 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0064 | Precision=0.931 | Recall=0.536 | Accuracy=0.996 | AUC=0.768
# 📌 Epoch 36/60
#    🏋️ Training: Total Loss=0.5047 | CE Loss=0.0761 | Rec Loss=0.4079 | MI Loss=2.4784
#    🔬 Kernel Bandwidths: s_x=31.0397 | s_y=22.8569
#    📊 SOLARIS - CE Loss=0.1326 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0544 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0033 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0040 | Precision=0.923 | Recall=0.895 | Accuracy=0.999 | AUC=0.947
#    📊 RARE - CE Loss=0.0149 | Precision=0.000 | Recall=0.000 | Accuracy=0.997 | AUC=0.500
#    📊 SLOWHTTPS - CE Loss=0.0126 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0084 | Precision=0.930 | Recall=0.531 | Accuracy=0.996 | AUC=0.765
# 📌 Epoch 39/60
#    🏋️ Training: Total Loss=0.4933 | CE Loss=0.0663 | Rec Loss=0.4064 | MI Loss=2.4678
#    🔬 Kernel Bandwidths: s_x=31.2856 | s_y=23.0284
#    📊 SOLARIS - CE Loss=0.1305 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0589 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0025 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0035 | Precision=0.923 | Recall=0.900 | Accuracy=0.999 | AUC=0.950
#    📊 RARE - CE Loss=0.0136 | Precision=0.375 | Recall=0.060 | Accuracy=0.997 | AUC=0.530
#    📊 SLOWHTTPS - CE Loss=0.0143 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0065 | Precision=0.930 | Recall=0.533 | Accuracy=0.996 | AUC=0.767
# 📌 Epoch 42/60
#    🏋️ Training: Total Loss=0.4903 | CE Loss=0.0635 | Rec Loss=0.4064 | MI Loss=2.4482
#    🔬 Kernel Bandwidths: s_x=31.5329 | s_y=23.2039
#    📊 SOLARIS - CE Loss=0.1393 | Precision=0.953 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0527 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0034 | Precision=0.926 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0043 | Precision=0.918 | Recall=0.895 | Accuracy=0.999 | AUC=0.947
#    📊 RARE - CE Loss=0.0108 | Precision=0.556 | Recall=0.133 | Accuracy=0.997 | AUC=0.567
#    📊 SLOWHTTPS - CE Loss=0.0115 | Precision=0.921 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0060 | Precision=0.926 | Recall=0.536 | Accuracy=0.996 | AUC=0.768
# 📌 Epoch 45/60
#    🏋️ Training: Total Loss=0.4927 | CE Loss=0.0643 | Rec Loss=0.4081 | MI Loss=2.4401
#    🔬 Kernel Bandwidths: s_x=31.7817 | s_y=23.3827
#    📊 SOLARIS - CE Loss=0.1369 | Precision=0.953 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0607 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0032 | Precision=0.926 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0036 | Precision=0.922 | Recall=0.945 | Accuracy=0.999 | AUC=0.972
#    📊 RARE - CE Loss=0.0154 | Precision=0.360 | Recall=0.060 | Accuracy=0.997 | AUC=0.530
#    📊 SLOWHTTPS - CE Loss=0.0162 | Precision=0.921 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0064 | Precision=0.926 | Recall=0.536 | Accuracy=0.996 | AUC=0.768
# 📌 Epoch 48/60
#    🏋️ Training: Total Loss=0.4799 | CE Loss=0.0600 | Rec Loss=0.3997 | MI Loss=2.4289
#    🔬 Kernel Bandwidths: s_x=32.0325 | s_y=23.5648
#    📊 SOLARIS - CE Loss=0.1495 | Precision=0.953 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0546 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0031 | Precision=0.926 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0035 | Precision=0.901 | Recall=0.730 | Accuracy=0.999 | AUC=0.865
#    📊 RARE - CE Loss=0.0120 | Precision=0.543 | Recall=0.127 | Accuracy=0.997 | AUC=0.563
#    📊 SLOWHTTPS - CE Loss=0.0135 | Precision=0.921 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0057 | Precision=0.924 | Recall=0.520 | Accuracy=0.996 | AUC=0.760
# 📌 Epoch 51/60
#    🏋️ Training: Total Loss=0.4804 | CE Loss=0.0595 | Rec Loss=0.4006 | MI Loss=2.4242
#    🔬 Kernel Bandwidths: s_x=32.2855 | s_y=23.7478
#    📊 SOLARIS - CE Loss=0.1441 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0651 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0019 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0024 | Precision=0.925 | Recall=0.925 | Accuracy=0.999 | AUC=0.962
#    📊 RARE - CE Loss=0.0132 | Precision=0.706 | Recall=0.240 | Accuracy=0.997 | AUC=0.620
#    📊 SLOWHTTPS - CE Loss=0.0189 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0041 | Precision=0.931 | Recall=0.536 | Accuracy=0.996 | AUC=0.768
# 📌 Epoch 54/60
#    🏋️ Training: Total Loss=0.4750 | CE Loss=0.0600 | Rec Loss=0.3949 | MI Loss=2.4033
#    🔬 Kernel Bandwidths: s_x=32.5403 | s_y=23.9324
#    📊 SOLARIS - CE Loss=0.1683 | Precision=0.951 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0602 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0022 | Precision=0.921 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0024 | Precision=0.917 | Recall=0.945 | Accuracy=0.999 | AUC=0.972
#    📊 RARE - CE Loss=0.0121 | Precision=0.691 | Recall=0.253 | Accuracy=0.997 | AUC=0.626
#    📊 SLOWHTTPS - CE Loss=0.0102 | Precision=0.917 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0042 | Precision=0.957 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 57/60
#    🏋️ Training: Total Loss=0.4761 | CE Loss=0.0562 | Rec Loss=0.4001 | MI Loss=2.3796
#    🔬 Kernel Bandwidths: s_x=32.7974 | s_y=24.1159
#    📊 SOLARIS - CE Loss=0.1533 | Precision=0.000 | Recall=0.000 | Accuracy=0.990 | AUC=0.500
#    📊 INFIL - CE Loss=0.0604 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0033 | Precision=0.875 | Recall=0.455 | Accuracy=0.998 | AUC=0.727
#    📊 GOLDEN_EYE - CE Loss=0.0037 | Precision=0.841 | Recall=0.345 | Accuracy=0.997 | AUC=0.672
#    📊 RARE - CE Loss=0.0115 | Precision=0.458 | Recall=0.073 | Accuracy=0.997 | AUC=0.537
#    📊 SLOWHTTPS - CE Loss=0.0190 | Precision=0.935 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0052 | Precision=0.966 | Recall=1.000 | Accuracy=1.000 | AUC=1.000
# 📌 Epoch 60/60
#    🏋️ Training: Total Loss=0.4689 | CE Loss=0.0574 | Rec Loss=0.3918 | MI Loss=2.3662
#    🔬 Kernel Bandwidths: s_x=33.0564 | s_y=24.3007
#    📊 SOLARIS - CE Loss=0.1681 | Precision=0.956 | Recall=0.656 | Accuracy=0.996 | AUC=0.828
#    📊 INFIL - CE Loss=0.0742 | Precision=0.000 | Recall=0.000 | Accuracy=0.994 | AUC=0.500
#    📊 BOTNET - CE Loss=0.0018 | Precision=0.930 | Recall=0.995 | Accuracy=1.000 | AUC=0.997
#    📊 GOLDEN_EYE - CE Loss=0.0019 | Precision=0.928 | Recall=0.960 | Accuracy=1.000 | AUC=0.980
#    📊 RARE - CE Loss=0.0140 | Precision=0.786 | Recall=0.367 | Accuracy=0.998 | AUC=0.683
#    📊 SLOWHTTPS - CE Loss=0.0157 | Precision=0.926 | Recall=0.499 | Accuracy=0.996 | AUC=0.749
#    📊 HOIC - CE Loss=0.0042 | Precision=0.931 | Recall=0.541 | Accuracy=0.996 | AUC=0.771
#
# ✅ Training complete. Full logs saved to 'segment_insertion_all_datasets.log'.
# Best AUC: 0.8688 at (λ_mse=1.000, λ_mi=0.000)

# %% [markdown]
# **RECONSTRUCTION 0.0, MI Penalty 0.0**

# %% [markdown]
# **RECONSTRUCTION 1.0, MI Penalty 0.0**

# %% [markdown]
# **RECONSTRUCTION 0.01, MI Penalty 0.99**

# %% [markdown]
# **RECONSTRUCTION 0.5, MI Penalty 0.5**

# %% [markdown]
# **Precision, recall, and accuracy plots for the rarest class (RARE, in blue)(OOD), which has only 525 samples in the CIC-IDS dataset using training data from GOLDENEYE (source) and BOTNET (cross) domains. case 1 show precision, recall, and AUC over epochs without regularization on validation data; case 2 apply MI = 0.01, reconstruction = 0.99; case 3 apply MI = 0.99, reconstruction = 0.01, case 4 use equal weights of 0.5  Regularization leads to over 10-20\% improvement and stability across all metrics. Higher MI penalty helps in acheiveing better classification of the RARE class. Although, we see that the performance of some other SOURCE classes like SOLARIS (in orange) detoriates but our goal here is to improve the performance of the RARE (OOD) class. This case is represented in Fig 2 of the paper. We apologize for the bad cropping for which the axis names are not clearly visible. It will be corrected.**
